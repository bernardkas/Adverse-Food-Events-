# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('CAERS_ASCII_2004_2017Q2.csv')

# %%
df
# Out:
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 0            65325              1/1/2004             8/4/2003
# 1            65325              1/1/2004             8/4/2003
# 2            65333              1/1/2004                  NaN
# 3            65335              1/1/2004           11/24/2003
# 4            65336              1/1/2004                  NaN
# ...            ...                   ...                  ...
# 90781       214516             6/29/2017            1/20/2017
# 90782       214516             6/29/2017            1/20/2017
# 90783       214516             6/29/2017            1/20/2017
# 90784       214604             6/30/2017                  NaN
# 90785       214610             6/30/2017                  NaN
#
#       PRI_Product Role                    PRI_Reported Brand/Product Name  \
# 0              Suspect      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# ...

# %%
df.shape
# Out:
# (90786, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90786 entries, 0 to 90785
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   RA_Report #                      90786 non-null  int64
#  1   RA_CAERS Created Date            90786 non-null  object
#  2   AEC_Event Start Date             53653 non-null  object
#  3   PRI_Product Role                 90786 non-null  object
#  4   PRI_Reported Brand/Product Name  90786 non-null  object
#  5   PRI_FDA Industry Code            90786 non-null  int64
#  6   PRI_FDA Industry Name            90786 non-null  object
#  7   CI_Age at Adverse Event          52926 non-null  float64
#  8   CI_Age Unit                      90786 non-null  object
#  9   CI_Gender                        90786 non-null  object
#  10  AEC_One Row Outcomes             90786 non-null  object
#  11  SYM_One Row Coded Symptoms       90781 non-null  object
# ...

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows', 85)

# %%
df
# Out:
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 0            65325              1/1/2004             8/4/2003
# 1            65325              1/1/2004             8/4/2003
# 2            65333              1/1/2004                  NaN
# 3            65335              1/1/2004           11/24/2003
# 4            65336              1/1/2004                  NaN
# ...            ...                   ...                  ...
# 90781       214516             6/29/2017            1/20/2017
# 90782       214516             6/29/2017            1/20/2017
# 90783       214516             6/29/2017            1/20/2017
# 90784       214604             6/30/2017                  NaN
# 90785       214610             6/30/2017                  NaN
#
#       PRI_Product Role                    PRI_Reported Brand/Product Name  \
# 0              Suspect      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# ...

# %%
df.head()
# Out:
#    RA_Report # RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# 0        65325              1/1/2004             8/4/2003          Suspect
# 1        65325              1/1/2004             8/4/2003          Suspect
# 2        65333              1/1/2004                  NaN          Suspect
# 3        65335              1/1/2004           11/24/2003          Suspect
# 4        65336              1/1/2004                  NaN          Suspect
#
#                      PRI_Reported Brand/Product Name  PRI_FDA Industry Code  \
# 0      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 1      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS                      3
# 2  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...                     13
# 3                         ENFAMIL LIPIL BABY FORMULA                     40
# 4                         ENFIMIL LIPIL BABY FORMULA                     40
#
# ...

# %%
df.head(10)
# Out:
#    RA_Report # RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# 0        65325              1/1/2004             8/4/2003          Suspect
# 1        65325              1/1/2004             8/4/2003          Suspect
# 2        65333              1/1/2004                  NaN          Suspect
# 3        65335              1/1/2004           11/24/2003          Suspect
# 4        65336              1/1/2004                  NaN          Suspect
# 5        65345              1/1/2004           12/21/2003          Suspect
# 6        65350              1/1/2004                  NaN          Suspect
# 7        65353              1/2/2004            12/1/2003          Suspect
# 8        65353              1/2/2004            12/1/2003          Suspect
# 9        65354              1/2/2004                  NaN          Suspect
#
#                      PRI_Reported Brand/Product Name  PRI_FDA Industry Code  \
# ...

# %%
df.tail(10)
# Out:
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 90776       214407             6/28/2017            3/10/2017
# 90777       214407             6/28/2017            3/10/2017
# 90778       214407             6/28/2017            3/10/2017
# 90779       214478             6/29/2017            6/20/2017
# 90780       214479             6/29/2017            6/20/2017
# 90781       214516             6/29/2017            1/20/2017
# 90782       214516             6/29/2017            1/20/2017
# 90783       214516             6/29/2017            1/20/2017
# 90784       214604             6/30/2017                  NaN
# 90785       214610             6/30/2017                  NaN
#
#       PRI_Product Role                    PRI_Reported Brand/Product Name  \
# 90776      Concomitant                                             ENSURE
# 90777      Concomitant  VITAMIN D3 (COLECALCIFEROL)(400 IU (INTERNATIO...
# ...

# %%
df['CI_Gender']
# Out:
# 0               Female
# 1               Female
# 2               Female
# 3        Not Available
# 4        Not Available
#              ...
# 90781           Female
# 90782           Female
# 90783           Female
# 90784           Female
# 90785    Not Available
# Name: CI_Gender, Length: 90786, dtype: object

# %%
df['CI_Gender'].value_counts()
# Out:
# Female           58924
# Male             26943
# Not Available     4916
# Unknown              2
# Not Reported         1
# Name: CI_Gender, dtype: int64

# %%
df.loc(0)

# %%
df.sort_index(ascending=False)
# Out:
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 90785       214610             6/30/2017                  NaN
# 90784       214604             6/30/2017                  NaN
# 90783       214516             6/29/2017            1/20/2017
# 90782       214516             6/29/2017            1/20/2017
# 90781       214516             6/29/2017            1/20/2017
# ...            ...                   ...                  ...
# 4            65336              1/1/2004                  NaN
# 3            65335              1/1/2004           11/24/2003
# 2            65333              1/1/2004                  NaN
# 1            65325              1/1/2004             8/4/2003
# 0            65325              1/1/2004             8/4/2003
#
#       PRI_Product Role                    PRI_Reported Brand/Product Name  \
# 90785          Suspect                    DR. PERICONE NECK & CHEST CREAM
# ...

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 0            65325              1/1/2004             8/4/2003
# 1            65325              1/1/2004             8/4/2003
# 2            65333              1/1/2004                  NaN
# 3            65335              1/1/2004           11/24/2003
# 4            65336              1/1/2004                  NaN
# ...            ...                   ...                  ...
# 90781       214516             6/29/2017            1/20/2017
# 90782       214516             6/29/2017            1/20/2017
# 90783       214516             6/29/2017            1/20/2017
# 90784       214604             6/30/2017                  NaN
# 90785       214610             6/30/2017                  NaN
#
#       PRI_Product Role                    PRI_Reported Brand/Product Name  \
# 0              Suspect      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# ...

# %%
df.sort_values('AEC_Event Start Date')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15884/316252697.py in <module>
# ----> 1 df.sort_values('AEC_Event Start Date')
#
# NameError: name 'df' is not defined

# %%
# Out:
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 0            65325              1/1/2004             8/4/2003
# 1            65325              1/1/2004             8/4/2003
# 2            65333              1/1/2004                  NaN
# 3            65335              1/1/2004           11/24/2003
# 4            65336              1/1/2004                  NaN
# ...            ...                   ...                  ...
# 90781       214516             6/29/2017            1/20/2017
# 90782       214516             6/29/2017            1/20/2017
# 90783       214516             6/29/2017            1/20/2017
# 90784       214604             6/30/2017                  NaN
# 90785       214610             6/30/2017                  NaN
#
#       PRI_Product Role                    PRI_Reported Brand/Product Name  \
# 0              Suspect      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# ...

# %%
import seaborn as sb

# %%
sb.countplot(df['CI_Gender'])
# Out:
# C:\Users\Berni\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CI_Gender', ylabel='count'>

# %%
df['CI_Age at Adverse Event'].median()
# Out:
# 53.0

# %%
df.median()
# Out:
# C:\Users\Berni\AppData\Local\Temp/ipykernel_1704/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# RA_Report #                168433.0
# PRI_FDA Industry Code          54.0
# CI_Age at Adverse Event        53.0
# dtype: float64

# %%
df.groupby(['SYM_One Row Coded Symptoms'])

# %%
country_group = df.groupby(['SYM_One Row Coded Symptoms'])

# %%
country_group.get_group('NAUSEA, DYSGEUSIA, DIARRHOEA')
# Out:
#    RA_Report # RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# 2        65333              1/1/2004                  NaN          Suspect
#
#                      PRI_Reported Brand/Product Name  PRI_FDA Industry Code  \
# 2  KROGER CLASSIC CREAM-DE-MINT CANDY MINT CHIP I...                     13
#
#   PRI_FDA Industry Name  CI_Age at Adverse Event    CI_Age Unit CI_Gender  \
# 2        Ice Cream Prod                      NaN  Not Available    Female
#
#   AEC_One Row Outcomes    SYM_One Row Coded Symptoms
# 2        VISITED AN ER  NAUSEA, DYSGEUSIA, DIARRHOEA

# %%
sb.countplot(df['SYM_One Row Coded Symptoms'])
# Out:
# C:\Users\Berni\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SYM_One Row Coded Symptoms', ylabel='count'>

# %%
country_group['CI_Gender'].value_counts().head(50)

# %%
sb.countplot(df['health'])
